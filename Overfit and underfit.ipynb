# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features)
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [[ 0.8692932  -0.6350818   0.22569026 ...  0.72165745  0.98875093
#    0.87667835]
#  [ 0.9075421   0.32914728  0.35941187 ...  0.77973217  0.99235576
#    0.7983426 ]
#  [ 0.79883474  1.4706388  -1.6359748  ...  0.8032515   0.8659244
#    0.7801176 ]
#  ...
#  [ 0.4814969  -0.44418392 -1.6454076  ...  0.64619136  0.6939376
#    0.6955113 ]
#  [ 0.56476605  0.26291743  0.5430709  ...  0.7223196   0.93818957
#    0.8478069 ]
#  [ 0.44105193  0.80152214 -0.33426744 ...  0.6051652   0.9711247
#    0.89249057]], shape=(1000, 28), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4725,  binary_crossentropy:0.7991,  loss:0.7991,  val_accuracy:0.4600,  val_binary_crossentropy:0.7762,  val_loss:0.7762,
# ....................................................................................................
# Epoch: 100, accuracy:0.5932,  binary_crossentropy:0.6300,  loss:0.6300,  val_accuracy:0.5640,  val_binary_crossentropy:0.6321,  val_loss:0.6321,
# ....................................................................................................
# Epoch: 200, accuracy:0.6089,  binary_crossentropy:0.6187,  loss:0.6187,  val_accuracy:0.5970,  val_binary_crossentropy:0.6194,  val_loss:0.6194,
# ....................................................................................................
# Epoch: 300, accuracy:0.6245,  binary_crossentropy:0.6111,  loss:0.6111,  val_accuracy:0.6100,  val_binary_crossentropy:0.6112,  val_loss:0.6112,
# ....................................................................................................
# Epoch: 400, accuracy:0.6365,  binary_crossentropy:0.6041,  loss:0.6041,  val_accuracy:0.6420,  val_binary_crossentropy:0.6014,  val_loss:0.6014,
# ....................................................................................................
# Epoch: 500, accuracy:0.6453,  binary_crossentropy:0.5969,  loss:0.5969,  val_accuracy:0.6490,  val_binary_crossentropy:0.5941,  val_loss:0.5941,
# ....................................................................................................
# Epoch: 600, accuracy:0.6582,  binary_crossentropy:0.5923,  loss:0.5923,  val_accuracy:0.6450,  val_binary_crossentropy:0.5900,  val_loss:0.5900,
# ....................................................................................................
# Epoch: 700, accuracy:0.6598,  binary_crossentropy:0.5890,  loss:0.5890,  val_accuracy:0.6400,  val_binary_crossentropy:0.5886,  val_loss:0.5886,
# ....................................................................................................
# Epoch: 800, accuracy:0.6672,  binary_crossentropy:0.5865,  loss:0.5865,  val_accuracy:0.6530,  val_binary_crossentropy:0.5849,  val_loss:0.5849,
# ....................................................................................................
# Epoch: 900, accuracy:0.6639,  binary_crossentropy:0.5850,  loss:0.5850,  val_accuracy:0.6470,  val_binary_crossentropy:0.5860,  val_loss:0.5860,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6709,  binary_crossentropy:0.5841,  loss:0.5841,  val_accuracy:0.6490,  val_binary_crossentropy:0.5847,  val_loss:0.5847,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6631,  binary_crossentropy:0.5832,  loss:0.5832,  val_accuracy:0.6590,  val_binary_crossentropy:0.5839,  val_loss:0.5839,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6704,  binary_crossentropy:0.5809,  loss:0.5809,  val_accuracy:0.6560,  val_binary_crossentropy:0.5840,  val_loss:0.5840,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6669,  binary_crossentropy:0.5804,  loss:0.5804,  val_accuracy:0.6570,  val_binary_crossentropy:0.5833,  val_loss:0.5833,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6764,  binary_crossentropy:0.5790,  loss:0.5790,  val_accuracy:0.6550,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6736,  binary_crossentropy:0.5780,  loss:0.5780,  val_accuracy:0.6600,  val_binary_crossentropy:0.5830,  val_loss:0.5830,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6653,  binary_crossentropy:0.5776,  loss:0.5776,  val_accuracy:0.6660,  val_binary_crossentropy:0.5820,  val_loss:0.5820,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6737,  binary_crossentropy:0.5767,  loss:0.5767,  val_accuracy:0.6610,  val_binary_crossentropy:0.5842,  val_loss:0.5842,
# ................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4875,  binary_crossentropy:0.7775,  loss:0.7775,  val_accuracy:0.5080,  val_binary_crossentropy:0.7256,  val_loss:0.7256,
# ....................................................................................................
# Epoch: 100, accuracy:0.6130,  binary_crossentropy:0.6184,  loss:0.6184,  val_accuracy:0.6000,  val_binary_crossentropy:0.6139,  val_loss:0.6139,
# ....................................................................................................
# Epoch: 200, accuracy:0.6489,  binary_crossentropy:0.5961,  loss:0.5961,  val_accuracy:0.6300,  val_binary_crossentropy:0.5956,  val_loss:0.5956,
# ....................................................................................................
# Epoch: 300, accuracy:0.6702,  binary_crossentropy:0.5815,  loss:0.5815,  val_accuracy:0.6610,  val_binary_crossentropy:0.5862,  val_loss:0.5862,
# ....................................................................................................
# Epoch: 400, accuracy:0.6804,  binary_crossentropy:0.5729,  loss:0.5729,  val_accuracy:0.6520,  val_binary_crossentropy:0.5883,  val_loss:0.5883,
# ....................................................................................................
# Epoch: 500, accuracy:0.6907,  binary_crossentropy:0.5682,  loss:0.5682,  val_accuracy:0.6750,  val_binary_crossentropy:0.5880,  val_loss:0.5880,
# ...................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4917,  binary_crossentropy:0.6944,  loss:0.6944,  val_accuracy:0.4730,  val_binary_crossentropy:0.6842,  val_loss:0.6842,
# ....................................................................................................
# Epoch: 100, accuracy:0.7145,  binary_crossentropy:0.5304,  loss:0.5304,  val_accuracy:0.6640,  val_binary_crossentropy:0.6067,  val_loss:0.6067,
# ....................................................................................................
# Epoch: 200, accuracy:0.7881,  binary_crossentropy:0.4386,  loss:0.4386,  val_accuracy:0.6410,  val_binary_crossentropy:0.6857,  val_loss:0.6857,
# ...........................................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5102,  binary_crossentropy:0.7474,  loss:0.7474,  val_accuracy:0.5120,  val_binary_crossentropy:0.6738,  val_loss:0.6738,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0018,  loss:0.0018,  val_accuracy:0.6620,  val_binary_crossentropy:1.8374,  val_loss:1.8374,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6710,  val_binary_crossentropy:2.4609,  val_loss:2.4609,
# .........................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
logdir
# Out:
# PosixPath('/tmp/tmpu8h3ar3m/tensorboard_logs')

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir {logdir}/sizes
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %%
logdir
# Out:
# PosixPath('/tmp/tmpu8h3ar3m/tensorboard_logs')

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# PosixPath('/tmp/tmpu8h3ar3m/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5065,  binary_crossentropy:0.7552,  loss:2.2604,  val_accuracy:0.4730,  val_binary_crossentropy:0.6968,  val_loss:2.1081,
# ....................................................................................................
# Epoch: 100, accuracy:0.6557,  binary_crossentropy:0.5947,  loss:0.6184,  val_accuracy:0.6260,  val_binary_crossentropy:0.5889,  val_loss:0.6125,
# ....................................................................................................
# Epoch: 200, accuracy:0.6671,  binary_crossentropy:0.5880,  loss:0.6116,  val_accuracy:0.7040,  val_binary_crossentropy:0.5815,  val_loss:0.6064,
# ....................................................................................................
# Epoch: 300, accuracy:0.6843,  binary_crossentropy:0.5694,  loss:0.5937,  val_accuracy:0.6900,  val_binary_crossentropy:0.5726,  val_loss:0.5967,
# ....................................................................................................
# Epoch: 400, accuracy:0.6977,  binary_crossentropy:0.5601,  loss:0.5857,  val_accuracy:0.6890,  val_binary_crossentropy:0.5720,  val_loss:0.5973,
# ....................................................................................................
# Epoch: 500, accuracy:0.7059,  binary_crossentropy:0.5513,  loss:0.5772,  val_accuracy:0.6890,  val_binary_crossentropy:0.5827,  val_loss:0.6086,
# .................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5009,  binary_crossentropy:0.8118,  loss:0.8118,  val_accuracy:0.4700,  val_binary_crossentropy:0.6808,  val_loss:0.6808,
# ....................................................................................................
# Epoch: 100, accuracy:0.6527,  binary_crossentropy:0.5990,  loss:0.5990,  val_accuracy:0.6770,  val_binary_crossentropy:0.5842,  val_loss:0.5842,
# ....................................................................................................
# Epoch: 200, accuracy:0.6844,  binary_crossentropy:0.5583,  loss:0.5583,  val_accuracy:0.6840,  val_binary_crossentropy:0.5827,  val_loss:0.5827,
# ....................................................................................................
# Epoch: 300, accuracy:0.7220,  binary_crossentropy:0.5093,  loss:0.5093,  val_accuracy:0.6730,  val_binary_crossentropy:0.6049,  val_loss:0.6049,
# ..............................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5032,  binary_crossentropy:0.8093,  loss:0.9675,  val_accuracy:0.5020,  val_binary_crossentropy:0.6791,  val_loss:0.8368,
# ....................................................................................................
# Epoch: 100, accuracy:0.6466,  binary_crossentropy:0.6034,  loss:0.6345,  val_accuracy:0.6500,  val_binary_crossentropy:0.5866,  val_loss:0.6176,
# ....................................................................................................
# Epoch: 200, accuracy:0.6623,  binary_crossentropy:0.5914,  loss:0.6175,  val_accuracy:0.6700,  val_binary_crossentropy:0.5758,  val_loss:0.6019,
# ....................................................................................................
# Epoch: 300, accuracy:0.6723,  binary_crossentropy:0.5785,  loss:0.6072,  val_accuracy:0.6870,  val_binary_crossentropy:0.5635,  val_loss:0.5921,
# ....................................................................................................
# Epoch: 400, accuracy:0.6765,  binary_crossentropy:0.5779,  loss:0.6087,  val_accuracy:0.6810,  val_binary_crossentropy:0.5559,  val_loss:0.5867,
# ....................................................................................................
# Epoch: 500, accuracy:0.6833,  binary_crossentropy:0.5727,  loss:0.6050,  val_accuracy:0.7030,  val_binary_crossentropy:0.5545,  val_loss:0.5868,
# ....................................................................................................
# Epoch: 600, accuracy:0.6871,  binary_crossentropy:0.5681,  loss:0.6022,  val_accuracy:0.6880,  val_binary_crossentropy:0.5502,  val_loss:0.5842,
# ....................................................................................................
# Epoch: 700, accuracy:0.6871,  binary_crossentropy:0.5637,  loss:0.5988,  val_accuracy:0.6870,  val_binary_crossentropy:0.5448,  val_loss:0.5799,
# ....................................................................................................
# Epoch: 800, accuracy:0.6868,  binary_crossentropy:0.5613,  loss:0.5980,  val_accuracy:0.6950,  val_binary_crossentropy:0.5496,  val_loss:0.5864,
# .............................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
logdir
# Out:
# PosixPath('/tmp/tmpu8h3ar3m/tensorboard_logs')
